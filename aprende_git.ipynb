# %% [markdown]
# <a href="https://colab.research.google.com/github/i-Abrajan/hola-colab/blob/main/aprende_git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola mundo desde Google Colab 🚀")
# Out:
# Hola mundo desde Google Colab 🚀
